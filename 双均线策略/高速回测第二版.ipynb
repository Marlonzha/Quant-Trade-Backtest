# %%
#思路,每次只找服务器要一个合约的k线数据,并同时测试不同策略，使用不同账户进行控制。
# %config DisplayFormatter.truncate_bytes = 10000

# %%
import json
import pandas as pd
from tqsdk import TqApi, TqAuth, TqBacktest, TargetPosTask, TqSim, TqMultiAccount
from datetime import date
from tqsdk.tafunc import ma,ema
from tqsdk.exceptions import BacktestFinished
import math


# strategy_name_list[0]= {'X_MA': 'MA', 'short': 5, 'long': 15}
def calculate_vwma(data, window_size):
    """
    计算成交量加权移动平均线（VWMA）
    :param data: 包含日期、收盘价和成交量的数据框
    :param window_size: 计算VWMA的窗口大小
    :return: 包含原始数据和VWMA的数据框
    """
    # 确保数据框中的价格和成交量列是数值类型
    data = data.copy()
    data['close'] = pd.to_numeric(data['close'])
    data['volume'] = pd.to_numeric(data['volume'])
    # 计算价格与成交量的乘积
    data['价格_成交量乘积'] = data['close'] * data['volume']
    # 计算VWMA
    data['VWMA'] = data['价格_成交量乘积'].rolling(window=window_size).sum() / data['volume'].rolling(window=window_size).sum()
    return data["VWMA"]

def craet_run_strategy(klines,strategy_params,target_pos_i):
    
    strategy_type = strategy_params["X_MA"]
    strategy_short = strategy_params["short"]
    strategy_long = strategy_params["long"]
    strategy_target_pos = target_pos_i
    if strategy_type == "MA":
        short_avg = ma(klines["close"], strategy_short)  # 短周期
        long_avg = ma(klines["close"],  strategy_long)  # 长周期
    elif strategy_type == "EMA":
        short_avg = ema(klines["close"], strategy_short)  # 短周期
        long_avg = ema(klines["close"],  strategy_long)  # 长周期
    elif strategy_type == "VWMA":
        short_avg = calculate_vwma(klines, strategy_short)  # 短周期
        long_avg = calculate_vwma(klines,  strategy_long)  # 长周期
    elif strategy_type == "MA+kσ":
        short_avg = ma(klines["close"], strategy_short)  # 短周期
        long_avg_top= ma(klines["close"],  strategy_long) + klines["close"].rolling(window=strategy_long).std()*0.2  # 长周期上轨道
        long_avg_bottom = ma(klines["close"],  strategy_long,) -  klines["close"].rolling(window=strategy_long).std()*0.2 # 长周期下轨道
        # 均线下穿，做空
        if long_avg_bottom.iloc[-3] < short_avg.iloc[-3] and long_avg_bottom.iloc[-2] > short_avg.iloc[-2]:
            strategy_target_pos.set_target_volume(-10)
        # 均线上穿，做多
        if short_avg.iloc[-3] < long_avg_top.iloc[-3] and short_avg.iloc[-2] > long_avg_top.iloc[-2]:
            strategy_target_pos.set_target_volume(10) 
        return
    else:
        print("X_MA参数输入错误")
        return 

    # 上穿，做多
    if long_avg.iloc[-3] > short_avg.iloc[-3] and long_avg.iloc[-2] < short_avg.iloc[-2]:
        strategy_target_pos.set_target_volume(10)
    # 下穿，做空
    if short_avg.iloc[-3] > long_avg.iloc[-3] and short_avg.iloc[-2] < long_avg.iloc[-2]:
       strategy_target_pos.set_target_volume(-10)
    return 
def create_backtest_record(R):
  data = {
      "策略-参数1":R["param_1"],
      "策略-参数2":R["param_2"],
      "策略-参数3":R["param_3"],
      "标的":R["标的"],
      "开始时间":R["start_date"],
      "结束时间":R["end_date"],

      "保证金" : R["保证金"],
      "使用金额" : max(R["保证金"]*10*2,R["report"]["max_drawdown"]*R["report"]["start_balance"]*2),
      "起始金额" : R["report"]["start_balance"],
      "结束金额" : R["report"]["end_balance"],
      "最大回撤" : R["report"]["max_drawdown"]*R["report"]["start_balance"]/(R["保证金"]*10*2)*100,
      "盈亏比" : R["report"]["profit_loss_ratio"],
      "胜率" : R["report"]["winning_rate"],
      "收益率" : (R["report"]["end_balance"]-R["report"]["start_balance"])/max(R["保证金"]*10*2,R["report"]["max_drawdown"]*R["report"]["start_balance"]*2)*100

  }
  return pd.DataFrame(data,index=[0])
def create_params(symbol,strategy_name_list):
    #测试标的
    symbol,start_date,end_date = symbol["symbol"],symbol["start_date"],symbol["end_date"]
    y,m,d = start_date.split("-")
    y,m,d = int(y),int(m),int(d)
    e_y,e_m,e_d = end_date.split("-")
    e_y,e_m,e_d = int(e_y),int(e_m),int(e_d)
    #开始和结束时间
    start_date = date(y,m,d)
    end_date = date(e_y,e_m,e_d)
   
    #按照策略总数量，生成模拟账号
    acc_list = [TqSim(10000000) for _ in range(len(strategy_name_list))]

    #最大的长周期，用于确认订阅的K线长度

    long = max([int(strategy_name_list[i]["long"]) for i in range(len(strategy_name_list))])
    

    return symbol,start_date,end_date,acc_list,long



#第一部分获取标的
symbols_pool_path = r"C:/Users/zhaoc/OneDrive/LH2024/HL2024-flask/策略研究/双均线策略/Symbols_and_Strategy/20250319标的池.json"
strategy_pool_path = r"C:/Users/zhaoc/OneDrive/LH2024/HL2024-flask/策略研究/双均线策略/Symbols_and_Strategy/策略池.json"
user_path = r"C:/Users/zhaoc/OneDrive/LH2024/HL2024-flask/策略研究/双均线策略/Symbols_and_Strategy/账户.json"
backtest_record_path = r"C:/Users/zhaoc/OneDrive/LH2024/HL2024-flask/策略研究/双均线策略/策略回测结果{}.csv".format(date.today().strftime("%Y%m%d"))

# 第二部分获取账户信息
with open(user_path,'r',encoding='utf8')as fp:
    json_data = json.load(fp)
    user = json_data['TQ_acc']

with open(symbols_pool_path,'r',encoding='utf8')as fp:
    json_data = json.load(fp)
    symbols = list(json_data['回测池——20250320'].values())

with open(strategy_pool_path,'r',encoding='utf8')as fp:
    json_data = json.load(fp)
    strategy_list = json_data['双均线策略-均线类型']
    param_list = json_data['双均线策略-均线周期']
    strategy_name_list = []
    for strategy in list(strategy_list.values()):
        for param in list(param_list.values()):
            strategy_name = {"X_MA": strategy,"short": param[0],"long": param[1]}
            strategy_name_list.append(strategy_name)





#需要的标的

result_dict_list = []
for symbol in symbols[0:1]:
    symbol,start_date,end_date,acc_list,long = create_params(symbol,strategy_name_list)
    api = TqApi(account=TqMultiAccount(acc_list),backtest=TqBacktest(start_dt=start_date, end_dt=end_date),auth=TqAuth(user["username"], user["password"]))
    quate = api.get_quote(symbol)
    margin = quate.margin
    klines = api.get_kline_serial(symbol, duration_seconds=60*60*24, data_length=long+3)
    target_pos_list = [TargetPosTask(api, symbol,account=acc_list[i]) for i in range(len(acc_list))]
    print("开始运行{}的回测".format(symbol))
    try:
        while True:
            api.wait_update()
            if api.is_changing(klines.iloc[-1], "datetime"):
                for i in range(len(strategy_name_list)):
                    craet_run_strategy(klines,strategy_name_list[i],target_pos_list[i])

    #strategy_name_list[0]= {'X_MA': 'MA', 'short': 5, 'long': 15}
    except BacktestFinished:
        print("回测结束")
        api.close()
        
        for r in range(len(acc_list)):
            result_dict = {"param_1":strategy_name_list[r]["X_MA"],
                                "param_2":str(strategy_name_list[r]["short"]),
                                "param_3":str(strategy_name_list[r]["long"]),
                                "标的":symbol,
                                "保证金" : margin,
                                "start_date":start_date,"end_date":end_date,"report":acc_list[r].tqsdk_stat}
            result_dict_list.append(create_backtest_record(result_dict))

backtest_record_df = pd.concat(result_dict_list)
backtest_record_df.to_csv(backtest_record_path,index=False)
# Out:
# 开始运行SHFE.au2402的回测
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_8883cc8139c90ce63e3d3ca27716c32c: 时间: 2023-01-30 09:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 420.09999999999997
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_8883cc8139c90ce63e3d3ca27716c32c: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_120f4d5b5fd8d53477e979721255c439: 时间: 2023-01-30 09:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 420.09999999999997
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_120f4d5b5fd8d53477e979721255c439: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_84063ac747d935a362297ce43a48f947: 时间: 2023-01-30 09:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 420.09999999999997
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_84063ac747d935a362297ce43a48f947: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_e0094a5fca1937c113f5ed85e660aba3: 时间: 2023-01-30 09:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 420.09999999999997
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_e0094a5fca1937c113f5ed85e660aba3: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_412cecf1c48d09d700fc496caf3dc956: 时间: 2023-02-06 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 417.46000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_412cecf1c48d09d700fc496caf3dc956: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_f446c7bed99dfa3578b18a70f80eec49: 时间: 2023-02-06 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 417.46000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_f446c7bed99dfa3578b18a70f80eec49: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_bbd75c007f5e15e4e6b15684b626e98c: 时间: 2023-02-07 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 415.66
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_bbd75c007f5e15e4e6b15684b626e98c: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_a6ac5b1b23b514cc2a7114d88ca74c3b: 时间: 2023-02-07 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 415.66
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_a6ac5b1b23b514cc2a7114d88ca74c3b: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_e971b0427baf8bd70552233375cf7e8a: 时间: 2023-02-08 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 416.44
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_e971b0427baf8bd70552233375cf7e8a: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_c9adb9d61b57fb053c899bb09bf217ab: 时间: 2023-02-08 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 416.44
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_c9adb9d61b57fb053c899bb09bf217ab: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_7e560212230a4575f9efeff9f983baaa: 时间: 2023-02-08 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 416.44
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_7e560212230a4575f9efeff9f983baaa: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_8146ba6914ca25fca1f46f02cfc8ad44: 时间: 2023-02-08 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 416.44
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_8146ba6914ca25fca1f46f02cfc8ad44: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_8af772e9606b627f0d5ae6474cb7b594: 时间: 2023-02-27 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 415.46
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_8af772e9606b627f0d5ae6474cb7b594: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_6a482dc0a9993540b443d14c6231f082: 时间: 2023-02-28 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 415.94
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_6a482dc0a9993540b443d14c6231f082: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_044551177a2536d6c13ac7fee53c592b: 时间: 2023-03-01 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 417.21999999999997
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_044551177a2536d6c13ac7fee53c592b: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_a17b90c71bf073c90b5ec2def7df4035: 时间: 2023-03-03 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 418.78
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_a17b90c71bf073c90b5ec2def7df4035: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_ed2137d17ae0723f0432263bc3067133: 时间: 2023-03-03 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 418.78
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_ed2137d17ae0723f0432263bc3067133: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_2c605e83bf1ab8eb977c3d63d3a0ae9b: 时间: 2023-03-07 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 421.7
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_2c605e83bf1ab8eb977c3d63d3a0ae9b: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_a3c45c89cd77972e9b0053da48185de2: 时间: 2023-03-07 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 421.7
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_a3c45c89cd77972e9b0053da48185de2: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_9dc5131ea14fe163dd124116b9ab0eb6: 时间: 2023-03-08 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 416.82
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_9dc5131ea14fe163dd124116b9ab0eb6: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_f3976b280fa4cd694838e7b57ac8e9b2: 时间: 2023-03-08 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 416.82
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_f3976b280fa4cd694838e7b57ac8e9b2: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_7e185e1021aa8e4951c07105b20eb16e: 时间: 2023-03-10 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 419.53999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_7e185e1021aa8e4951c07105b20eb16e: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_9b35bfa0c61eee18687ef1ae434f085a: 时间: 2023-03-10 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 419.53999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_9b35bfa0c61eee18687ef1ae434f085a: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_3eddc3d749ef666035ce62f6718d12fd: 时间: 2023-03-13 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 425.78
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_3eddc3d749ef666035ce62f6718d12fd: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_b0e4b494429450fc6df387c069a77792: 时间: 2023-03-13 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 425.78
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_b0e4b494429450fc6df387c069a77792: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_3aeccd937ed355065c8cf4324896f64b: 时间: 2023-03-13 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 425.78
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_3aeccd937ed355065c8cf4324896f64b: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_033d33f6267f0cf427ca88f4e98d2580: 时间: 2023-03-14 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 428.4
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_033d33f6267f0cf427ca88f4e98d2580: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_03257e5736d21c4e5688d9f44e4ba61c: 时间: 2023-03-14 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 428.4
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_03257e5736d21c4e5688d9f44e4ba61c: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_1880145838e0c600e62d03d8f0e71065: 时间: 2023-03-15 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 430.4
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_1880145838e0c600e62d03d8f0e71065: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_697bfa38e00156fafde845c7bdf9f025: 时间: 2023-03-15 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 430.4
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_697bfa38e00156fafde845c7bdf9f025: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_57010eb11893d8bd732e662aaa1d943c: 时间: 2023-03-21 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 441.4
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_57010eb11893d8bd732e662aaa1d943c: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_910605acfc816b9671ea722f0fadd6ce: 时间: 2023-04-21 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 446.1
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_910605acfc816b9671ea722f0fadd6ce: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_487e37c52ab2b2da15fd0da596e1f8f7: 时间: 2023-04-21 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 446.1
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_487e37c52ab2b2da15fd0da596e1f8f7: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_01fab74970dc3231fdc453cce4fb9782: 时间: 2023-04-24 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 445.84000000000003
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_01fab74970dc3231fdc453cce4fb9782: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_8b50cb17d4ff1b02a358ac04ea879a0f: 时间: 2023-04-24 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 445.84000000000003
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_8b50cb17d4ff1b02a358ac04ea879a0f: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_c1f41c1187de0089c56ea5a1914ced1a: 时间: 2023-04-24 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 445.84000000000003
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_c1f41c1187de0089c56ea5a1914ced1a: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_49287fa2d26f0221a8779600334a24d7: 时间: 2023-04-24 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 445.84000000000003
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_49287fa2d26f0221a8779600334a24d7: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_276062aee920311312569326e96e1ca8: 时间: 2023-05-04 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 458.03999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_276062aee920311312569326e96e1ca8: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_be50e7d4e449956f0fc20e7096ae8564: 时间: 2023-05-04 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 458.03999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_be50e7d4e449956f0fc20e7096ae8564: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_dce1c2aee774d63635f3238cbcbe39df: 时间: 2023-05-04 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 458.03999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_dce1c2aee774d63635f3238cbcbe39df: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_aaf7b1c629534ade8853a23af596477f: 时间: 2023-05-04 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 458.03999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_aaf7b1c629534ade8853a23af596477f: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_470da4655f59b078afecba5926f0d078: 时间: 2023-05-04 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 458.03999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_470da4655f59b078afecba5926f0d078: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_3cbbfe27444653af775630b7b7511b79: 时间: 2023-05-04 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 458.03999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_3cbbfe27444653af775630b7b7511b79: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_35a5d48e4e24269198a550824d2a64c7: 时间: 2023-05-18 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 451.04
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_35a5d48e4e24269198a550824d2a64c7: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_88a80f50ee1a7bdec7772ca5f58f1bfe: 时间: 2023-05-18 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 451.04
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_88a80f50ee1a7bdec7772ca5f58f1bfe: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_bf883537818930503ea5e334c50a4153: 时间: 2023-05-18 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 451.04
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_bf883537818930503ea5e334c50a4153: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_88206a59bf52e0206fb7567b8d29148d: 时间: 2023-05-18 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 451.04
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_88206a59bf52e0206fb7567b8d29148d: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_837d5525f6deea75b026337a857121ef: 时间: 2023-05-19 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 448.74
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_837d5525f6deea75b026337a857121ef: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_cda5b0b9faeec3b9468873dea1393b99: 时间: 2023-05-19 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 448.74
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_cda5b0b9faeec3b9468873dea1393b99: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_882617cc8ec8e6e5b923b4e648fea4b5: 时间: 2023-05-19 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 448.74
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_882617cc8ec8e6e5b923b4e648fea4b5: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_de50b2b84a948a9f6cbd369b76e127a9: 时间: 2023-05-19 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 448.74
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_de50b2b84a948a9f6cbd369b76e127a9: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_e9510f069e96310698ba63659e0a9265: 时间: 2023-05-26 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 447.72
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_e9510f069e96310698ba63659e0a9265: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_9d58f784c930f9458b0b710fc466a1b3: 时间: 2023-05-26 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 447.72
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_9d58f784c930f9458b0b710fc466a1b3: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_d177154ab3bcbb951b613585846bd248: 时间: 2023-05-29 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 448.56
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_d177154ab3bcbb951b613585846bd248: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_e3988ce6491e4125c312e7aad364ac58: 时间: 2023-05-29 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 448.56
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_e3988ce6491e4125c312e7aad364ac58: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_3bf62b8cbdf4afa70303e263bf115411: 时间: 2023-05-30 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 450.38
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_3bf62b8cbdf4afa70303e263bf115411: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_1ba6db12a0a61ad4dd352cddc49d8fb7: 时间: 2023-05-30 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 450.38
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_1ba6db12a0a61ad4dd352cddc49d8fb7: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_f75d0feabce900af1bb863da217930c9: 时间: 2023-06-02 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 453.29999999999995
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_f75d0feabce900af1bb863da217930c9: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_d47441732c20dd3f208ad3ecb97e4f1a: 时间: 2023-06-02 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 453.29999999999995
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_d47441732c20dd3f208ad3ecb97e4f1a: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_8231367b6e3478f14237e04e08b2649a: 时间: 2023-06-05 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 450.08
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_8231367b6e3478f14237e04e08b2649a: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_44e94427b5645afc990889920337b792: 时间: 2023-06-05 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 450.08
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_44e94427b5645afc990889920337b792: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_d11b27ef6e27d575c9480bcf24816a50: 时间: 2023-06-05 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 450.08
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_d11b27ef6e27d575c9480bcf24816a50: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_c3ad87286a676b03e583525fa5326e52: 时间: 2023-06-05 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 450.08
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_c3ad87286a676b03e583525fa5326e52: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_ea445fef0518271d79872638148a8aa4: 时间: 2023-06-06 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 453.82
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_ea445fef0518271d79872638148a8aa4: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_32fc801be118ce1b9da78aa514f1420c: 时间: 2023-06-06 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 453.82
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_32fc801be118ce1b9da78aa514f1420c: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_121d11b003ae8580c58dddb406f8829c: 时间: 2023-06-12 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 455.58000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_121d11b003ae8580c58dddb406f8829c: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_8cc8c2039da9918b7c419179b7160951: 时间: 2023-06-12 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 455.58000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_8cc8c2039da9918b7c419179b7160951: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_f6cc9838a837449c3e8c3e87d8e60c3b: 时间: 2023-06-13 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 455.94
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_f6cc9838a837449c3e8c3e87d8e60c3b: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_400398473a1b7c46e9f88a6dc923de0c: 时间: 2023-06-13 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 455.94
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_400398473a1b7c46e9f88a6dc923de0c: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_ff5992c4285c5226ebf1c85c39944e5c: 时间: 2023-06-19 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 454.34
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_ff5992c4285c5226ebf1c85c39944e5c: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_404c215f05552bcec3b71a8b8cec355b: 时间: 2023-06-19 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 454.34
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_404c215f05552bcec3b71a8b8cec355b: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_e8d233b8cbf88900479ff3bacfc3f2da: 时间: 2023-06-19 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 454.34
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_e8d233b8cbf88900479ff3bacfc3f2da: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_614ae57e3d12ff22a8c7bb213d50cff2: 时间: 2023-06-19 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 454.34
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_614ae57e3d12ff22a8c7bb213d50cff2: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_529d53d670c8f3c1b993dbd22413b864: 时间: 2023-06-20 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 453.68
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_529d53d670c8f3c1b993dbd22413b864: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_6b96f81266da66429be4ea9bdbb87258: 时间: 2023-06-20 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 453.68
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_6b96f81266da66429be4ea9bdbb87258: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_7dd3214268cb5fb0d34e4f264cd8c840: 时间: 2023-06-26 09:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 451.52000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_7dd3214268cb5fb0d34e4f264cd8c840: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_b11819a027f98cc9ceedad9eb6e3dc60: 时间: 2023-06-26 09:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 451.52000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_b11819a027f98cc9ceedad9eb6e3dc60: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_64edaead65223c5f7cfdd3c8a0fee520: 时间: 2023-06-26 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 454.38
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_64edaead65223c5f7cfdd3c8a0fee520: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_dae82bd1220ee15c639287067f663767: 时间: 2023-06-26 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 454.38
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_dae82bd1220ee15c639287067f663767: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_036da95bfea77167286462177a056a4a: 时间: 2023-06-27 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 452.22
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_036da95bfea77167286462177a056a4a: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_a2132df196a20db41a5f9cc721d03f25: 时间: 2023-06-27 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 452.22
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_a2132df196a20db41a5f9cc721d03f25: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_293bb62815911f8da7e0fd3ce7cf0893: 时间: 2023-06-28 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 450.98
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_293bb62815911f8da7e0fd3ce7cf0893: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_a693d861bd564e57c1a345c6c168f6b5: 时间: 2023-06-28 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 450.98
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_a693d861bd564e57c1a345c6c168f6b5: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_d3675dc25563949f7f698bc76f5b5ae6: 时间: 2023-06-28 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 450.98
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_d3675dc25563949f7f698bc76f5b5ae6: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_feede3ee17d3815dc6ffdca265956452: 时间: 2023-06-28 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 450.98
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_feede3ee17d3815dc6ffdca265956452: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_4150fcd84b29162f100a0be1666140e7: 时间: 2023-06-29 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 449.68
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_4150fcd84b29162f100a0be1666140e7: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_f1e9663ac499be1a561c1e7f672dd35b: 时间: 2023-06-29 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 449.71999999999997
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_f1e9663ac499be1a561c1e7f672dd35b: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_e71f1bfc981627adbf6465822dd2989d: 时间: 2023-06-29 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 449.68
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_e71f1bfc981627adbf6465822dd2989d: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_eb1d7802b8912a19889a3f924e0cd322: 时间: 2023-06-29 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 449.71999999999997
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_eb1d7802b8912a19889a3f924e0cd322: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_9fbb23ce157e131ce45cdcba4c272250: 时间: 2023-06-30 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 453.02000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_9fbb23ce157e131ce45cdcba4c272250: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_d2dda637cb29e2b2ab86cfdd57d260fc: 时间: 2023-06-30 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 453.02000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_d2dda637cb29e2b2ab86cfdd57d260fc: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_fd48a0afb0ed29818749cc9e61e3153c: 时间: 2023-07-03 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 453.64
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_fd48a0afb0ed29818749cc9e61e3153c: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_d6aa76ee383a70103e7f0b13721868bb: 时间: 2023-07-03 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 453.64
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_d6aa76ee383a70103e7f0b13721868bb: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_1b6142293c0285a868328e43894f7923: 时间: 2023-07-05 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 454.94
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_1b6142293c0285a868328e43894f7923: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_aa56a4fdae8ba9b561dd75f776a45630: 时间: 2023-07-05 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 454.94
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_aa56a4fdae8ba9b561dd75f776a45630: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_cc7141a95691eeb2b6067a9ff50d9074: 时间: 2023-07-05 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 454.94
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_cc7141a95691eeb2b6067a9ff50d9074: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_0a0bfa5229f3f5f676b52552ae3668fc: 时间: 2023-07-05 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 454.94
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_0a0bfa5229f3f5f676b52552ae3668fc: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_18222bb19014ecc07b10df2715f56862: 时间: 2023-07-06 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 451.15999999999997
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_18222bb19014ecc07b10df2715f56862: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_9bc4462ac000d7df356093b60fcfa092: 时间: 2023-07-06 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 451.15999999999997
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_9bc4462ac000d7df356093b60fcfa092: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_a27c1b26d6257df22e3f1e637fee05b6: 时间: 2023-07-06 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 451.15999999999997
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_a27c1b26d6257df22e3f1e637fee05b6: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_f77f4805ada5a01c311274d7b4bde5a9: 时间: 2023-07-06 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 451.15999999999997
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_f77f4805ada5a01c311274d7b4bde5a9: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_752a99d8822f054fe0277d5d14f737a3: 时间: 2023-07-10 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 452.35999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_752a99d8822f054fe0277d5d14f737a3: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_eefeb240ce44bc505d077ea1634cdeb2: 时间: 2023-07-10 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 452.35999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_eefeb240ce44bc505d077ea1634cdeb2: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_7318cef7113e9293b5f74c7b0ce8c971: 时间: 2023-07-12 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 455.02
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_7318cef7113e9293b5f74c7b0ce8c971: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_634ea515c5a9e92702791757b0e9396b: 时间: 2023-07-12 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 455.02
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_634ea515c5a9e92702791757b0e9396b: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_b0d4a203065a947c54817bc1cba272fc: 时间: 2023-08-02 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 458.64000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_b0d4a203065a947c54817bc1cba272fc: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_df34c81aaa2dc902e78dda737073ce5c: 时间: 2023-08-02 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 458.64000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_df34c81aaa2dc902e78dda737073ce5c: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_dfe23e51c144bc5b2d18edc985b26270: 时间: 2023-08-02 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 458.64000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_dfe23e51c144bc5b2d18edc985b26270: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_ec409c2d91a1c7caa782f9345e65dd09: 时间: 2023-08-02 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 458.64000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_ec409c2d91a1c7caa782f9345e65dd09: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_fc5e6edafd08109f0009477f23b15fc0: 时间: 2023-08-03 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 456.12
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_fc5e6edafd08109f0009477f23b15fc0: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_49539465e91e666f7fbe0ccc5f285baa: 时间: 2023-08-03 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 456.12
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_49539465e91e666f7fbe0ccc5f285baa: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_8ed3bf763f01a7a41f161cc3e4c89cd7: 时间: 2023-08-03 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 456.12
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_8ed3bf763f01a7a41f161cc3e4c89cd7: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_489708ede52e6180ccd906f40bc18a61: 时间: 2023-08-03 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 456.12
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_489708ede52e6180ccd906f40bc18a61: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_a47a539cbc7f4d0a09aa52282431c745: 时间: 2023-08-10 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 456.38
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_a47a539cbc7f4d0a09aa52282431c745: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_847c834b0e1a209c58eb5019c64d23f8: 时间: 2023-08-10 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 456.38
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_847c834b0e1a209c58eb5019c64d23f8: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_f891fd06018f338e0b12fe0eaaf1252f: 时间: 2023-08-14 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 457.54
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_f891fd06018f338e0b12fe0eaaf1252f: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_046f11cbda0295a26cdf90c2d779974f: 时间: 2023-08-14 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 457.54
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_046f11cbda0295a26cdf90c2d779974f: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_a9f3f1857844587cc4ccc4eaf4afc12c: 时间: 2023-08-16 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 458.48
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_a9f3f1857844587cc4ccc4eaf4afc12c: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_13fb7efdc2082de2d91e25c026ca1913: 时间: 2023-08-16 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 458.48
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_13fb7efdc2082de2d91e25c026ca1913: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_ad08d4cda7c98c115311e60d5e7ec5d2: 时间: 2023-08-17 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 457.97999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_ad08d4cda7c98c115311e60d5e7ec5d2: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_32d2ab67318b99b5f5dc96a38693b993: 时间: 2023-08-17 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 457.97999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_32d2ab67318b99b5f5dc96a38693b993: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_ea95844e98347f70c16f7ab26ed929b1: 时间: 2023-08-17 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 457.97999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_ea95844e98347f70c16f7ab26ed929b1: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_0f8bbe21f9654bb8495530b1b3217ad2: 时间: 2023-08-17 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 457.97999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_0f8bbe21f9654bb8495530b1b3217ad2: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_a8b6ab1fac94e0d4934a7290817f35d8: 时间: 2023-08-17 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 457.97999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_a8b6ab1fac94e0d4934a7290817f35d8: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_8e1d7fe47e71b0810c34fc3cff074bf6: 时间: 2023-08-17 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 457.97999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_8e1d7fe47e71b0810c34fc3cff074bf6: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_0ba3b9f8209dec73b3a6c05f852e1026: 时间: 2023-08-18 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 456.18
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_0ba3b9f8209dec73b3a6c05f852e1026: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_00eef8c7cc4a87b52a91cb47ec24eb82: 时间: 2023-08-18 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 456.18
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_00eef8c7cc4a87b52a91cb47ec24eb82: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_669b6586e1b5494ea75d120359a5448a: 时间: 2023-08-18 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 456.18
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_669b6586e1b5494ea75d120359a5448a: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_141c01d47038a5cc7a43f00c5b9d9669: 时间: 2023-08-18 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 456.18
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_141c01d47038a5cc7a43f00c5b9d9669: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_ad4839ea9575cf00d2022d5cbec218eb: 时间: 2023-08-21 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 457.85999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_ad4839ea9575cf00d2022d5cbec218eb: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_078d033fd42cf36dda02bf7e5320170d: 时间: 2023-08-21 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 457.85999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_078d033fd42cf36dda02bf7e5320170d: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_93c646c120e3dd33a4f036b016d73031: 时间: 2023-08-22 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 458.03999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_93c646c120e3dd33a4f036b016d73031: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_06ffe9fbe6433ed0f8ce4a77e9825b96: 时间: 2023-08-22 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 458.03999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_06ffe9fbe6433ed0f8ce4a77e9825b96: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_cb958647065397985cd79c36c9dfd5c1: 时间: 2023-08-23 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 459.34
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_cb958647065397985cd79c36c9dfd5c1: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_36a745d73d23c814f1f406393b20d7ac: 时间: 2023-08-23 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 459.34
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_36a745d73d23c814f1f406393b20d7ac: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_3f14c49240d804184c9d3e54972fc56a: 时间: 2023-08-24 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 460.3
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_3f14c49240d804184c9d3e54972fc56a: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_f5c8e140b12bba15ec2788b83d864bd8: 时间: 2023-08-24 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 460.3
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_f5c8e140b12bba15ec2788b83d864bd8: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_db8f24cf4e196ba4c88a7a8525eec036: 时间: 2023-08-28 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 460.52
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_db8f24cf4e196ba4c88a7a8525eec036: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_9712cab2696c6a6802b070d3022f44f5: 时间: 2023-08-28 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 460.52
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_9712cab2696c6a6802b070d3022f44f5: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_b09997869e6b0553eb19e51da7538fdc: 时间: 2023-08-29 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 460.97999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_b09997869e6b0553eb19e51da7538fdc: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_df58e210130e695a6ee397e4bd65a33b: 时间: 2023-08-29 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 460.97999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_df58e210130e695a6ee397e4bd65a33b: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_e1d47f64255bc589cbd2739300bc17a3: 时间: 2023-08-30 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 463.82
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_e1d47f64255bc589cbd2739300bc17a3: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_54fb70c200486a58c4b903a4ac00ee8f: 时间: 2023-08-30 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 463.82
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_54fb70c200486a58c4b903a4ac00ee8f: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_9c0775ae115696b94bb12bf56457bd4a: 时间: 2023-08-30 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 463.82
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_9c0775ae115696b94bb12bf56457bd4a: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_b35cef39c5c6e6006ba1fe0524fbbbf5: 时间: 2023-08-30 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 463.82
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_b35cef39c5c6e6006ba1fe0524fbbbf5: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_7dead38ce6ce74c3a8171c3af23700e4: 时间: 2023-10-09 09:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 456.0
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_7dead38ce6ce74c3a8171c3af23700e4: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_2cf8131050e8873c44c4b54c48709681: 时间: 2023-10-09 09:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 456.0
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_2cf8131050e8873c44c4b54c48709681: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_edc2e4952712d9d7201c88b8f30b09f5: 时间: 2023-10-09 09:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 456.0
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_edc2e4952712d9d7201c88b8f30b09f5: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_d38ac15ec1dbb64fe94875f557cf90c6: 时间: 2023-10-09 09:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 456.0
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_d38ac15ec1dbb64fe94875f557cf90c6: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_ffb92cbf4e9ecbba77463f0c2d5944ea: 时间: 2023-10-09 09:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 456.0
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_ffb92cbf4e9ecbba77463f0c2d5944ea: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_ae89899359735db1bb82fc995f861cb8: 时间: 2023-10-09 09:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 456.0
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_ae89899359735db1bb82fc995f861cb8: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_e8ff4e1cbed01d40ec6cff733d70dbe5: 时间: 2023-10-09 09:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 456.0
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_e8ff4e1cbed01d40ec6cff733d70dbe5: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_02ea8a23219caf7083027cca8a5d9e3b: 时间: 2023-10-09 09:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 456.0
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_02ea8a23219caf7083027cca8a5d9e3b: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_9d4a3dd115be403e19440d93e69e0438: 时间: 2023-10-10 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 451.8
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_9d4a3dd115be403e19440d93e69e0438: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_88f49fd9f40c80c6903f5cf2830c3489: 时间: 2023-10-10 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 451.8
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_88f49fd9f40c80c6903f5cf2830c3489: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_64cdca28f8db8d333ad599f53adc8ec3: 时间: 2023-10-10 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 451.8
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_64cdca28f8db8d333ad599f53adc8ec3: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_e5130a21c2ddd3e2638901784ee39410: 时间: 2023-10-10 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 451.8
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_e5130a21c2ddd3e2638901784ee39410: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_b0b37b6f8b872b585a5c3a88d55fe673: 时间: 2023-10-11 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 452.82
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_b0b37b6f8b872b585a5c3a88d55fe673: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_2fca6fee2cbcd69ab7ed2e150ce3eed0: 时间: 2023-10-11 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 452.82
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_2fca6fee2cbcd69ab7ed2e150ce3eed0: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_d36a0b9d5bb2b54a569d3e2c929768da: 时间: 2023-10-12 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 454.40000000000003
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_d36a0b9d5bb2b54a569d3e2c929768da: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_541e79f39ec0a75ce34f0f756358fcf0: 时间: 2023-10-12 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 454.40000000000003
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_541e79f39ec0a75ce34f0f756358fcf0: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_805e645c00bec97ecb8ecd4e330cc424: 时间: 2023-10-13 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 463.72
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_805e645c00bec97ecb8ecd4e330cc424: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_49b8743aaffda55b3dc310691458cc5b: 时间: 2023-10-13 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 463.72
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_49b8743aaffda55b3dc310691458cc5b: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_38962052d0397a29179a365c9eb2d76f: 时间: 2023-10-18 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 470.97999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_38962052d0397a29179a365c9eb2d76f: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_28a1f84db2a478d782f6f3161b97dbea: 时间: 2023-10-18 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 470.97999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_28a1f84db2a478d782f6f3161b97dbea: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_fc3f4f8f0e976417c8d35608b3f2d4db: 时间: 2023-10-18 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 470.97999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_fc3f4f8f0e976417c8d35608b3f2d4db: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_030cfb31a59e37a931e59df6cd3efc73: 时间: 2023-10-18 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 470.97999999999996
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_030cfb31a59e37a931e59df6cd3efc73: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_c3b6d796f168bcf26c3e509e1647db7d: 时间: 2023-10-19 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 473.18
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_c3b6d796f168bcf26c3e509e1647db7d: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_9c358f52bcaadb8bb628d4d5751f1089: 时间: 2023-10-19 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 473.18
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_9c358f52bcaadb8bb628d4d5751f1089: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_9a175c7cde56f0b8e08245ef43015d9c: 时间: 2023-10-19 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 473.18
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_9a175c7cde56f0b8e08245ef43015d9c: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_f3df35b49b9e20afc232f376bf24bd1a: 时间: 2023-10-19 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 473.18
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_f3df35b49b9e20afc232f376bf24bd1a: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_5c0991a15e4f6dcbadef5fbb5fe4119e: 时间: 2023-10-19 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 473.18
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_5c0991a15e4f6dcbadef5fbb5fe4119e: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_31dfdf1fa2b0bccbe5843d0f1b415108: 时间: 2023-10-19 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 473.18
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_31dfdf1fa2b0bccbe5843d0f1b415108: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_fd809d9519b4adf95ca94397dcc148d2: 时间: 2023-10-20 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 476.64
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_fd809d9519b4adf95ca94397dcc148d2: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_913d44c9409a38aa0b03aa54f010b7d0: 时间: 2023-10-20 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 476.64
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_913d44c9409a38aa0b03aa54f010b7d0: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_811afc884940cba43419b8fea34314fe: 时间: 2023-10-24 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 474.12
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_811afc884940cba43419b8fea34314fe: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_8265302bb9ef6a369fe439c40c277ffd: 时间: 2023-10-24 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 474.12
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_8265302bb9ef6a369fe439c40c277ffd: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_18936f4a527b06bbcfc459603b759c91: 时间: 2023-10-25 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 475.84
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_18936f4a527b06bbcfc459603b759c91: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_a6963d960cf66cb0497309271bf4bbce: 时间: 2023-10-25 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 475.84
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_a6963d960cf66cb0497309271bf4bbce: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_e8ce8d7b92fadc6bbcbc9beb03a4141a: 时间: 2023-10-25 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 475.84
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_e8ce8d7b92fadc6bbcbc9beb03a4141a: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_09bd1defbbea51f8c6a7649533162c05: 时间: 2023-10-25 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: BUY, 手数: 10, 价格: 475.84
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_09bd1defbbea51f8c6a7649533162c05: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_8bd2a8de17f3dd9567ad5739710a09eb: 时间: 2023-11-08 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 471.42
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_8bd2a8de17f3dd9567ad5739710a09eb: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_b259fd5b8756000a54008529bf026594: 时间: 2023-11-08 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 471.42
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_b259fd5b8756000a54008529bf026594: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_9c1ff5f489cc82cdaa69d917e1c107c0: 时间: 2023-11-08 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 471.42
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_9c1ff5f489cc82cdaa69d917e1c107c0: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_1598cbcc61d77169bdfb3641521d86ba: 时间: 2023-11-08 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 471.42
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_1598cbcc61d77169bdfb3641521d86ba: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_0c1d3288dec70f98805e1228d888e8a0: 时间: 2023-11-08 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 471.42
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_0c1d3288dec70f98805e1228d888e8a0: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_1d40520e29dee937673dcdd753b8fd4b: 时间: 2023-11-08 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 471.42
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_1d40520e29dee937673dcdd753b8fd4b: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_0d5b7cfc7daf540156968151d9e768a4: 时间: 2023-11-09 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 468.46000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_0d5b7cfc7daf540156968151d9e768a4: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_b8876349930d209e4cc252c95de76d51: 时间: 2023-11-09 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 468.46000000000004
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_b8876349930d209e4cc252c95de76d51: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_cfa2fb49f605f1e4e93c5218e1363ae0: 时间: 2023-11-20 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 466.68
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_cfa2fb49f605f1e4e93c5218e1363ae0: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_e633214577959f1c607e98903f0abfdf: 时间: 2023-11-20 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 466.68
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_e633214577959f1c607e98903f0abfdf: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_ab862a4b055e461f329e538ddb9f7a5e: 时间: 2023-11-21 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 466.62
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_ab862a4b055e461f329e538ddb9f7a5e: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_80fa86b6bba2ab4ba5138ab73b860d95: 时间: 2023-11-21 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 466.62
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_80fa86b6bba2ab4ba5138ab73b860d95: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_ac2a38b7e3f57b84b1c3951a09ffcfff: 时间: 2023-11-21 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 466.62
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_ac2a38b7e3f57b84b1c3951a09ffcfff: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_dbb13335ad60514f54d71c7a98f2bccb: 时间: 2023-11-21 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 466.62
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_dbb13335ad60514f54d71c7a98f2bccb: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_bed9657a41088b14f7e873fe1e7cc469: 时间: 2023-11-22 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: SELL, 手数: 10, 价格: 466.98
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_bed9657a41088b14f7e873fe1e7cc469: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_6f815f29608bc7b65f2ab5c64646d294: 时间: 2023-11-22 21:00:00.000000, 合约: SHFE.au2402, 开平: OPEN, 方向: SELL, 手数: 10, 价格: 466.98
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_6f815f29608bc7b65f2ab5c64646d294: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_c416b3d5f9188d9ad1fbe3b09a4d8a9e: 时间: 2023-11-29 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 475.18
#     INFO - 模拟交易委托单 TQSIM, PYSDK_target_c416b3d5f9188d9ad1fbe3b09a4d8a9e: 全部成交
#     INFO - 模拟交易下单 TQSIM, PYSDK_target_e2d6b93709912a1532866a340dd07fcf: 时间: 2023-11-29 21:00:00.000000, 合约: SHFE.au2402, 开平: CLOSE, 方向: BUY, 手数: 10, 价格: 475.18
# ...
#     INFO - 日期: 2023-09-27, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-09-28, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-09, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-10, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-11, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-12, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-13, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-16, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-17, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-18, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-19, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-20, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-23, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-24, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-25, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-26, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-27, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-30, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-10-31, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-01, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-02, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-03, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-06, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-07, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-08, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-09, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-10, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-13, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-14, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-15, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-16, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-17, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-20, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-21, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-22, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-23, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-24, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-27, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-28, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-29, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-11-30, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-12-01, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-12-04, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-12-05, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-12-06, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-12-07, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-12-08, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-12-11, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-12-12, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-12-13, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-12-14, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-12-15, 账户权益: 10000000.00, 可用资金: 10000000.00, 浮动盈亏: 0.00, 持仓盈亏: 0.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 0.00, 手续费: 0.00, 风险度: 0.00%
#     INFO - 日期: 2023-12-18, 账户权益: 9983500.00, 可用资金: 9743000.00, 浮动盈亏: -16400.00, 持仓盈亏: -16400.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 100.00, 风险度: 2.41%
#     INFO - 日期: 2023-12-19, 账户权益: 9993500.00, 可用资金: 9753000.00, 浮动盈亏: -6400.00, 持仓盈亏: 10000.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.41%
#     INFO - 日期: 2023-12-20, 账户权益: 10003700.00, 可用资金: 9763200.00, 浮动盈亏: 3800.00, 持仓盈亏: 10200.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.40%
#     INFO - 日期: 2023-12-21, 账户权益: 10004700.00, 可用资金: 9764200.00, 浮动盈亏: 4800.00, 持仓盈亏: 1000.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.40%
#     INFO - 日期: 2023-12-22, 账户权益: 10029900.00, 可用资金: 9789400.00, 浮动盈亏: 30000.00, 持仓盈亏: 25200.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.40%
#     INFO - 日期: 2023-12-25, 账户权益: 10042500.00, 可用资金: 9802000.00, 浮动盈亏: 42600.00, 持仓盈亏: 12600.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.39%
#     INFO - 日期: 2023-12-26, 账户权益: 10048500.00, 可用资金: 9808000.00, 浮动盈亏: 48600.00, 持仓盈亏: 6000.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.39%
#     INFO - 日期: 2023-12-27, 账户权益: 10060500.00, 可用资金: 9820000.00, 浮动盈亏: 60600.00, 持仓盈亏: 12000.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.39%
#     INFO - 日期: 2023-12-28, 账户权益: 10070500.00, 可用资金: 9830000.00, 浮动盈亏: 70600.00, 持仓盈亏: 10000.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.39%
#     INFO - 日期: 2023-12-29, 账户权益: 10051500.00, 可用资金: 9811000.00, 浮动盈亏: 51600.00, 持仓盈亏: -19000.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.39%
#     INFO - 日期: 2024-01-02, 账户权益: 10067700.00, 可用资金: 9827200.00, 浮动盈亏: 67800.00, 持仓盈亏: 16200.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.39%
#     INFO - 日期: 2024-01-03, 账户权益: 10061700.00, 可用资金: 9821200.00, 浮动盈亏: 61800.00, 持仓盈亏: -6000.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.39%
#     INFO - 日期: 2024-01-04, 账户权益: 10043100.00, 可用资金: 9802600.00, 浮动盈亏: 43200.00, 持仓盈亏: -18600.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.39%
#     INFO - 日期: 2024-01-05, 账户权益: 10050300.00, 可用资金: 9809800.00, 浮动盈亏: 50400.00, 持仓盈亏: 7200.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.39%
#     INFO - 日期: 2024-01-08, 账户权益: 10043700.00, 可用资金: 9803200.00, 浮动盈亏: 43800.00, 持仓盈亏: -6600.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.39%
#     INFO - 日期: 2024-01-09, 账户权益: 10037900.00, 可用资金: 9797400.00, 浮动盈亏: 38000.00, 持仓盈亏: -5800.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.40%
#     INFO - 日期: 2024-01-10, 账户权益: 10026900.00, 可用资金: 9786400.00, 浮动盈亏: 27000.00, 持仓盈亏: -11000.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.40%
#     INFO - 日期: 2024-01-11, 账户权益: 10029500.00, 可用资金: 9789000.00, 浮动盈亏: 29600.00, 持仓盈亏: 2600.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.40%
#     INFO - 日期: 2024-01-12, 账户权益: 10034900.00, 可用资金: 9794400.00, 浮动盈亏: 35000.00, 持仓盈亏: 5400.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.40%
#     INFO - 日期: 2024-01-15, 账户权益: 10063500.00, 可用资金: 9823000.00, 浮动盈亏: 63600.00, 持仓盈亏: 28600.00, 平仓盈亏: 0.00, 市值: 0.00, 保证金: 240500.00, 手续费: 0.00, 风险度: 2.39%
#     INFO - 胜率: 0.00%, 盈亏额比例: inf, 收益率: 0.64%, 年化收益率: 0.65%, 最大回撤: 0.43%, 年化夏普率: -2.9764,年化索提诺比率: -4.2497
# 回测结束
# ---------------------------------------------------------------------------
# BacktestFinished                          Traceback (most recent call last)
# Cell In[31], line 146
#     145 while True:
# --> 146     api.wait_update()
#     147     if api.is_changing(klines.iloc[-1], "datetime"):
#
# File c:\Users\zhaoc\.conda\envs\HL2025\lib\site-packages\tqsdk\api.py:1908, in TqApi.wait_update(self, deadline, _task)
#    1907             _set_running_loop(None)
# -> 1908     return self._wait_update(deadline=deadline, _task=_task)
#    1909 finally:
#
# File c:\Users\zhaoc\.conda\envs\HL2025\lib\site-packages\tqsdk\api.py:1938, in TqApi._wait_update(self, deadline, _task)
#    1937 try:
# -> 1938     self._run_until_task_done(task=update_task, deadline=deadline)
#    1939     return len(self._pending_diffs) != 0
#
# File c:\Users\zhaoc\.conda\envs\HL2025\lib\site-packages\tqsdk\baseApi.py:115, in TqBaseApi._run_until_task_done(self, task, deadline)
#     114 if len(self._wait_idle_list) == 0:
# --> 115     self._run_once()
#     116 else:
#
# File c:\Users\zhaoc\.conda\envs\HL2025\lib\site-packages\tqsdk\baseApi.py:84, in TqBaseApi._run_once(self)
#      83 if self._exceptions:
# ---> 84     raise self._exceptions.pop(0)
#
# File c:\Users\zhaoc\.conda\envs\HL2025\lib\site-packages\tqsdk\backtest\backtest.py:192, in TqBacktest._run(self, api, sim_send_chan, sim_recv_chan, md_send_chan, md_recv_chan)
#     191             self._pending_peek = True
# --> 192             await self._send_diff()
#     193 finally:
#     194     # 关闭所有 generator
#
# File c:\Users\zhaoc\.conda\envs\HL2025\lib\site-packages\tqsdk\backtest\backtest.py:296, in TqBacktest._send_diff(self)
#     295 if self._pending_peek:
# --> 296     await self._generator_diffs(True if self._diffs else False)
#     297     if self._diffs:
#     298         # 发送数据集中添加 backtest 字段，开始时间、结束时间、当前时间，表示当前行情推进是由 backtest 推进
#
# File c:\Users\zhaoc\.conda\envs\HL2025\lib\site-packages\tqsdk\backtest\backtest.py:376, in TqBacktest._generator_diffs(self, keep_current)
#     375     await self._api._wait_until_idle()
# --> 376     raise BacktestFinished(self._api) from None
#     377 # 把 quote 对应的 diffs 添加到 self._diffs 中
#
# BacktestFinished: 回测结束
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 163
#     156         for r in range(len(acc_list)):
#     157             result_dict = {"param_1":strategy_name_list[i]["X_MA"],
#     158                                 "param_2":str(strategy_name_list[i]["short"]),
#     159                                 "param_3":str(strategy_name_list[i]["long"]),
#     160                                 "标的":symbol,
#     161                                 "保证金" : margin,
#     162                                 "start_date":start_date,"end_date":end_date,"report":acc_list[i].tqsdk_stat}
# --> 163             result_dict_list.append(create_backtest_record(result_dict))
#     165 backtest_record_df = pd.concat(result_dict_list)
#     166 backtest_record_df.to_csv(backtest_record_path,index=False)
#
# Cell In[31], line 84, in create_backtest_record(R)
#      65 def create_backtest_record(R):
#      66   data = {
#      67       "策略-参数1":R["param_1"],
#      68       "策略-参数2":R["param_2"],
#    (...)
#      82
#      83   }
# ---> 84   return pd.DataFrame(data)
#
# File c:\Users\zhaoc\.conda\envs\HL2025\lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\zhaoc\.conda\envs\HL2025\lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\zhaoc\.conda\envs\HL2025\lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\zhaoc\.conda\envs\HL2025\lib\site-packages\pandas\core\internals\construction.py:667, in _extract_index(data)
#     664         raise ValueError("Per-column arrays must each be 1-dimensional")
#     666 if not indexes and not raw_lengths:
# --> 667     raise ValueError("If using all scalar values, you must pass an index")
#     669 if have_series:
#     670     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
def create_backtest_record(R):
  data = {
      "策略-参数1":R["param_1"],
      "策略-参数2":R["param_2"],
      "策略-参数3":R["param_3"],
      "标的":R["标的"],
      "开始时间":R["start_date"],
      "结束时间":R["end_date"],

      "保证金" : R["保证金"],
      "使用金额" : max(R["保证金"]*10*2,R["report"]["max_drawdown"]*R["report"]["start_balance"]*2),
      "起始金额" : R["report"]["start_balance"],
      "结束金额" : R["report"]["end_balance"],
      "最大回撤" : R["report"]["max_drawdown"]*R["report"]["start_balance"]/(R["保证金"]*10*2)*100,
      "盈亏比" : R["report"]["profit_loss_ratio"],
      "胜率" : R["report"]["winning_rate"],
      "收益率" : (R["report"]["end_balance"]-R["report"]["start_balance"])/max(R["保证金"]*10*2,R["report"]["max_drawdown"]*R["report"]["start_balance"]*2)*100

  }
  return pd.DataFrame(data,index=[0])
for r in range(len(acc_list)):
    result_dict = {"param_1":strategy_name_list[r]["X_MA"],
                        "param_2":str(strategy_name_list[r]["short"]),
                        "param_3":str(strategy_name_list[r]["long"]),
                        "标的":symbol,
                        "保证金" : margin,
                        "start_date":start_date,"end_date":end_date,"report":acc_list[r].tqsdk_stat}
    result_dict_list.append(create_backtest_record(result_dict))

# %%
backtest_record_df = pd.concat(result_dict_list)
backtest_record_df.to_csv(backtest_record_path,index=False)

# %%
#!/usr/bin/python3

import threading
import time

exitFlag = 0

class myThread (threading.Thread):
    def __init__(self, threadID, name, delay):
        threading.Thread.__init__(self)
        self.threadID = threadID
        self.name = name
        self.delay = delay
    def run(self):
        print ("开始线程：" + self.name)
        print_time(self.name, self.delay, 5)
        print ("退出线程：" + self.name)

def print_time(threadName, delay, counter):
    while counter:
        if exitFlag:
            threadName.exit()
        time.sleep(delay)
        print ("%s: %s" % (threadName, time.ctime(time.time())))
        counter -= 1

# 创建新线程
thread_list = []
for i in range(1, 3):
    thread = myThread(i, "Thread-{}".format(i), i)  
    thread.start()
    thread_list.append(thread)

for t in thread_list:
    t.join()

print ("退出主线程")
# Out:
# 开始线程：Thread-1
# 开始线程：Thread-2
# Thread-1: Mon Mar 31 01:01:25 2025
# Thread-2: Mon Mar 31 01:01:26 2025
# Thread-1: Mon Mar 31 01:01:26 2025
# Thread-1: Mon Mar 31 01:01:27 2025
# Thread-2: Mon Mar 31 01:01:28 2025
# Thread-1: Mon Mar 31 01:01:28 2025
# Thread-1: Mon Mar 31 01:01:29 2025
# 退出线程：Thread-1
# Thread-2: Mon Mar 31 01:01:30 2025
# Thread-2: Mon Mar 31 01:01:32 2025
# Thread-2: Mon Mar 31 01:01:34 2025
# 退出线程：Thread-2
# 退出主线程

# %%
start_backtest_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
print("开始回测时间:{}".format(start_backtest_time))
# Out:
# 开始回测时间:2025-03-31 02:51:32
